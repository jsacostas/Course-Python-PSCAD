# %% [markdown]
# <h1>Index<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Basic-graphs" data-toc-modified-id="Basic-graphs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Basic graphs</a></span><ul class="toc-item"><li><span><a href="#sub-plots" data-toc-modified-id="sub-plots-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>sub plots</a></span></li><li><span><a href="#Adding-text" data-toc-modified-id="Adding-text-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Adding text</a></span></li><li><span><a href="#Ploting-more-than-one-signal" data-toc-modified-id="Ploting-more-than-one-signal-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Ploting more than one signal</a></span></li><li><span><a href="#Adding-legends" data-toc-modified-id="Adding-legends-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Adding legends</a></span></li><li><span><a href="#Saving-figures" data-toc-modified-id="Saving-figures-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Saving figures</a></span></li></ul></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exercise</a></span></li></ul></div>

# %% [markdown]
# # Introduction
#
# *matplotlib* is a package for graphics creation. The syntax is similar to Matlab on purpose.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Basic graphs

# %%
import numpy as np

x = np.linspace(-5, 50)
y = x ** 2 - 45 * x + 5

plt.plot(x, y, 'r-.')

plt.title('Function', fontsize = 20)
plt.xlabel('x [m]', fontsize = 15)
plt.ylabel('y [m]', fontsize = 15)

plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)

plt.show()
plt.close()

# %% [markdown]
# ## sub plots

# %%
plt.rcParams.update({'font.size': 15})
plt.figure(figsize = (15,3))

plt.subplot(1,3,1)
plt.plot(x, y)

plt.subplot(1,3,2)
plt.scatter(x, y)

plt.subplot(1,3,3)
plt.scatter(x, -y, c = 'r')

plt.show()
plt.close()

# %%
fig, axes = plt.subplots(nrows = 2, ncols=2, figsize=(10,10))

axes[0, 0].plot(x, y, c='C0')
axes[0, 1].scatter(x, y, c='C1')
axes[1, 0].plot(x, -y, c='C2')
axes[1, 1].scatter(x, -y, c='C3')

plt.show()
plt.close()

# %% [markdown]
# ## Adding text
#
# Note that you can also add latex notation

# %%
plt.plot(x, y)

ymin = y.min()
xmin = x[y.argmin()]

plt.text(xmin, ymin, '|')
plt.text(10, 100, r'$\sum_{i=0}^{10} x^2 - 45 \cdot x + 5$')  

plt.show()
plt.close()

# %% [markdown]
# ## Ploting more than one signal

# %%
x = np.linspace(0, 4 * np.pi, 200)

y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.figure(figsize=(15,5))
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

plt.ylim((-2, 2))
plt.xlim((0, 4 * np.pi))
plt.axhline(0, color='k') 

plt.show()
plt.close()

# %% [markdown]
# ## Adding legends

# %%
plt.figure(figsize =(10,4))

plt.plot(x, y1, label = 'sin')
plt.plot(x, y2, label = 'cos')
plt.plot(x, y3, label = 'tan')

plt.legend(fontsize = 15)

plt.ylim((-2, 2))
plt.xlim((0, 4 * np.pi))
plt.axhline(0, color='k') 

plt.show()
plt.close()

# %% [markdown]
# ## Saving figures
#
# Figures can be saved with the function `savefig` in different formats:
#
# * `png`
# * `pdf`
# * `ps`
# * `eps`
# * `svg`

# %%
x = np.linspace(0, 4 * np.pi, 200)
y1 = np.sin(x)
y2 = np.cos(x)

plt.figure(figsize=(15,5))
plt.plot(x, y1, label='sin')
plt.plot(x, y2, label='cos')
plt.legend(title='Function', ncol=2, loc='upper right')
plt.ylim((-1, 1))

plt.savefig('sin_cos.png', dpi = 150, bbox_inches= 'tight')

plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0,60e-3,100)

va = np.sin(377*t)
vb = np.sin(377*t - 2*np.pi/3)
vc = np.sin(377*t + 2*np.pi/3)

plt.figure(figsize=(15,5))
plt.plot(t,va, label = "Va")
plt.plot(t,vb, label = "Vb")
plt.plot(t,vc, label = "Vc")

tvamax = t[va.argmax()]
plt.text(tvamax, va.max(), 'Max of the phase A') 

plt.legend(loc = 1)
plt.show()

# %% [markdown]
# # Exercise
#
# Use Pandas and matplotlib to plot 3 signals of the file **.\ATP\estudio_v2.txt**.
