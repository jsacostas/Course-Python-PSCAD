# %% [markdown]
# <h1>Index<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Mathematical-operations" data-toc-modified-id="Mathematical-operations-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Mathematical operations</a></span></li><li><span><a href="#Logic-Operations" data-toc-modified-id="Logic-Operations-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Logic Operations</a></span></li><li><span><a href="#Variables" data-toc-modified-id="Variables-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Variables</a></span><ul class="toc-item"><li><span><a href="#Changing-variable-types" data-toc-modified-id="Changing-variable-types-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Changing variable types</a></span></li><li><span><a href="#Mixing-numbers-and-strings:" data-toc-modified-id="Mixing-numbers-and-strings:-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Mixing numbers and strings:</a></span></li></ul></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exercise</a></span></li></ul></div>

# %% [markdown]
# # Mathematical operations

# %%
print(1 +  2, '\t', type(1 + 2)) 
print(1. - 2, '\t', type(1. - 2))  
print(1 * 2j, '\t', type(1*2j))  
print(1 /  2, '\t', type(1/2))  
print(10 % 3, '\t', type(10 % 3))  
print(10 // 3,'\t', type(10 // 3)) 
print(10 ** 3,'\t', type(10 ** 3))
# Out:
# 3 	 <class 'int'>
# -1.0 	 <class 'float'>
# 2j 	 <class 'complex'>
# 0.5 	 <class 'float'>
# 1 	 <class 'int'>
# 3 	 <class 'int'>
# 1000 	 <class 'int'>

# %% [markdown]
# The operator **+** also allows you to concatenate strings:

# %%
print('ABC' + 'def')
# Out:
# ABCdef

# %% [markdown]
# # Logic Operations

# %%
a = 1
b = a
c = 2
d = 3

print(a == b)
print(a != b)
print(a < c)
print(a <= c)
print(a > c)
print(a >= c)
# Out:
# True
# False
# True
# True
# False
# False

# %% [markdown]
# # Variables
# You can assing a variable using ```name = value```

# %%
a = 1
b = 2
c = a + b
print(c)
# Out:
# 3

# %%
a = '1'
b = '2'
c = a + b
print(c)
# Out:
# 12

# %% [markdown]
# ## Changing variable types
#
# You can change a variable type using the functions:
# ```python
# int(), float(), bool(), complex(), str()
# ```

# %%
a = '1'
b = '2'
a = int(a)
b = int(b)
c = a + b
print(c)
# Out:
# 3

# %% [markdown]
# Or:

# %%
a = 1
b = 2
a = str(a)
b = str(b)
c = a + b
print(c)
# Out:
# 12

# %% [markdown]
# ## Mixing numbers and strings:
#
# It is required when you need to show in the screen the result of a simulation. You can do it in different ways:

# %%
result = 3.252627
print ('The result is %s' % result)
print ('The result is ' +  str(result))
print ('The result is ' +  str(round(result,2)))
print ('The result is {}'.format(round(result, 2)) )
print ('The result is {0:.2f}'.format(result))
print (f'The result is {result:.2f}')
# Out:
# The result is 3.252627
# The result is 3.252627
# The result is 3.25
# The result is 3.25
# The result is 3.25
# The result is 3.25

# %% [markdown]
# If you have some doubts you can look in [internet](https://docs.python.org/3.7/library/string.html?highlight=string%20float%20notation#format-string-syntax).

# %% [markdown]
# # Exercise
# Create independent variables for your name, age, and nationality. Then, with just one print function show all of them in the screen

# %%
# write your code here
